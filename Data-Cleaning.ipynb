# %%
import pandas as pd

# %%
df = pd.read_csv('imdb.title.ratings.csv.gz')

# %%
df.head(3)
# Out:
#        tconst  averagerating  numvotes
# 0  tt10356526            8.3        31
# 1  tt10384606            8.9       559
# 2   tt1042974            6.4        20

# %%
df.tail(5)
# Out:
#           tconst  averagerating  numvotes
# 73851  tt9805820            8.1        25
# 73852  tt9844256            7.5        24
# 73853  tt9851050            4.7        14
# 73854  tt9886934            7.0         5
# 73855  tt9894098            6.3       128

# %%
df = pd.read_csv('bom.movie_gross.csv.gz')

# %%
df.head(3)
# Out:
#                                          title studio  domestic_gross  \
# 0                                  Toy Story 3     BV     415000000.0
# 1                   Alice in Wonderland (2010)     BV     334200000.0
# 2  Harry Potter and the Deathly Hallows Part 1     WB     296000000.0
#
#   foreign_gross  year
# 0     652000000  2010
# 1     691300000  2010
# 2     664300000  2010

# %%
df.tail(5)
# Out:
#                             title      studio  domestic_gross foreign_gross  \
# 3382                    The Quake       Magn.          6200.0           NaN
# 3383  Edward II (2018 re-release)          FM          4800.0           NaN
# 3384                     El Pacto        Sony          2500.0           NaN
# 3385                     The Swan  Synergetic          2400.0           NaN
# 3386            An Actor Prepares       Grav.          1700.0           NaN
#
#       year
# 3382  2018
# 3383  2018
# 3384  2018
# 3385  2018
# 3386  2018

# %%
df = pd.read_csv('imdb.title.basics.csv.gz')

# %%
df.head(3)
# Out:
#       tconst                    primary_title              original_title  \
# 0  tt0063540                        Sunghursh                   Sunghursh
# 1  tt0066787  One Day Before the Rainy Season             Ashad Ka Ek Din
# 2  tt0069049       The Other Side of the Wind  The Other Side of the Wind
#
#    start_year  runtime_minutes              genres
# 0        2013            175.0  Action,Crime,Drama
# 1        2019            114.0     Biography,Drama
# 2        2018            122.0               Drama

# %%
import pandas as pd
df = pd.read_csv('bom.movie_gross.csv.gz')
df.isna().sum()
# Out:
# title                0
# studio               5
# domestic_gross      28
# foreign_gross     1350
# year                 0
# dtype: int64

# %%
print(df)
# Out:
#                                             title      studio  domestic_gross  \
# 0                                     Toy Story 3          BV     415000000.0
# 1                      Alice in Wonderland (2010)          BV     334200000.0
# 2     Harry Potter and the Deathly Hallows Part 1          WB     296000000.0
# 3                                       Inception          WB     292600000.0
# 4                             Shrek Forever After        P/DW     238700000.0
# ...                                           ...         ...             ...
# 3382                                    The Quake       Magn.          6200.0
# 3383                  Edward II (2018 re-release)          FM          4800.0
# 3384                                     El Pacto        Sony          2500.0
# 3385                                     The Swan  Synergetic          2400.0
# 3386                            An Actor Prepares       Grav.          1700.0
#
#      foreign_gross  year
# ...

# %%
import pandas as pd
from bs4 import BeautifulSoup
import requests
html_page = requests.get('https://www.the-numbers.com/market/genres') #Make a request to retrieve the page
pd.read_html(html_page.text)
# Out:
# [    Rank                Genre  Movies Total Box Office     Tickets   Share
#  0      1            Adventure    1066  $64,001,503,244  9164697427  27.31%
#  1      2               Action    1044  $47,382,716,974  6713382234  20.22%
#  2      3                Drama    5381  $36,553,463,239  5611024748  15.60%
#  3      4               Comedy    2373  $34,518,271,413  5307865492  14.73%
#  4      5    Thriller/Suspense    1142  $20,012,264,504  2891232957   8.54%
#  5      6               Horror     639  $12,210,394,255  1764485285   5.21%
#  6      7      Romantic Comedy     606   $9,992,711,819  1607346807   4.26%
#  7      8              Musical     189   $4,108,333,804   542440825   1.75%
#  8      9          Documentary    2356   $2,241,568,251   336532152   0.96%
#  9     10         Black Comedy     193   $1,626,100,061   227572268   0.69%
#  10    11              Western      84   $1,151,006,490   165133802   0.49%
# ...

# %%
df=pd.read_html(html_page.text,index_col=0)[0]
df
# Out:
#                     Genre  Movies Total Box Office     Tickets   Share
# Rank
# 1               Adventure    1066  $64,001,503,244  9164697427  27.31%
# 2                  Action    1044  $47,382,716,974  6713382234  20.22%
# 3                   Drama    5381  $36,553,463,239  5611024748  15.60%
# 4                  Comedy    2373  $34,518,271,413  5307865492  14.73%
# 5       Thriller/Suspense    1142  $20,012,264,504  2891232957   8.54%
# 6                  Horror     639  $12,210,394,255  1764485285   5.21%
# 7         Romantic Comedy     606   $9,992,711,819  1607346807   4.26%
# 8                 Musical     189   $4,108,333,804   542440825   1.75%
# 9             Documentary    2356   $2,241,568,251   336532152   0.96%
# 10           Black Comedy     193   $1,626,100,061   227572268   0.69%
# 11                Western      84   $1,151,006,490   165133802   0.49%
# 12    Concert/Performance      76     $396,337,577    54011544   0.17%
# ...

# %%
soup = BeautifulSoup(html_page.content, 'html.parser') #Pass the page contents to beautiful soup for parsing

# %%
soup.prettify
# Out:
# <bound method Tag.prettify of <!DOCTYPE html>
#
# <html xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://ogp.me/ns#">
# <head>
# <!-- Global site tag (gtag.js) - Google Analytics -->
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-1343128-1"></script>
# <script>
#   window.dataLayer = window.dataLayer || [];
#   function gtag(){dataLayer.push(arguments);}
#   gtag('js', new Date());
#
#   gtag('config', 'UA-1343128-1');
# </script>
# <meta content='(PICS-1.1 "https://www.icra.org/ratingsv02.html" l gen true for "https://www.the-numbers.com/" r (cb 1 lz 1 nz 1 oz 1 vz 1) "https://www.rsac.org/ratingsv01.html" l gen true for "https://www.the-numbers.com/" r (n 0 s 0 v 0 l 0))' http-equiv="PICS-Label"/>
# <!--<meta http-equiv="Content-Type" content="text/html; charset=ISO-8859-1" >-->
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="telephone=no" name="format-detection"/> <!-- for apple mobile -->
# ...

# %%
market_share = soup.find('div',id ="page_filling_chart")
market_share # Previewing is optional but can help you verify you are selecting what you think you are
# Out:
# <div id="page_filling_chart">
# <p>
# <a href="/market">Market Charts</a> &gt; Genres
# <iframe frameborder="0" height="360" name="/graphs/market/all-items/genre/genres/7/Genres" scrolling="no" src="/graphs/market/all-items/genre/genres/7/Genres" width="760">You need a Frames Capable browser to view this content.</iframe>
# <b>Note:</b> Figures for 2020 are at an annualized rate.
# <h1>Market Share for Each Genre 1995-2020</h1>
# <center>
# <table>
# <tr><th>Rank</th><th>Genre</th><th>Movies</th><th>Total Box Office</th><th>Tickets</th><th>Share</th></tr>
# <tr>
# <td class="data">1</td>
# <td><b><a href="/market/genre/Adventure">Adventure</a></b></td>
# <td class="data">1,066</td>
# <td class="data">$64,001,417,525</td>
# <td class="data">9,164,688,017</td>
# <td class="data">27.31%</td>
# </tr>
# <tr>
# <td class="data">2</td>
# <td><b><a href="/market/genre/Action">Action</a></b></td>
# <td class="data">1,044</td>
# <td class="data">$47,382,716,974</td>
# ...

# %%
genres = market_share.findAll('tr')
genres[0]
# Out:
# <tr><th>Rank</th><th>Genre</th><th>Movies</th><th>Total Box Office</th><th>Tickets</th><th>Share</th></tr>

# %%
genres[1].find('a')
# Out:
# <a href="/market/genre/Adventure">Adventure</a>

# %%
genres[1].find('a').text
# Out:
# 'Adventure'

# %%
final_genres = findAll('tr').text
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-76-d23b5668228a> in <module>
# ----> 1 final_genres = market_share.findAll('tr').text
#
# ~\anaconda3\lib\site-packages\bs4\element.py in __getattr__(self, key)
#    2158     def __getattr__(self, key):
#    2159         """Raise a helpful exception to explain a common code fix."""
# -> 2160         raise AttributeError(
#    2161             "ResultSet object has no attribute '%s'. You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?" % key
#    2162         )
#
# AttributeError: ResultSet object has no attribute 'text'. You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?

# %%
import pandas as pd
import numpy as np
import datetime
from bs4 import BeautifulSoup
import requests
html_page = requests.get('https://www.the-numbers.com/movies/report/All/All/All/All/All/All/All/All/All/None/None/None/None/None/None/None/None/None/None?show-release-date=On&view-order-by=domestic-box-office&show-release-year=On&view-order-direction=desc&show-domestic-box-office=On&show-international-box-office=On&show-worldwide-box-office=On&show-genre=On') #Make a request to retrieve the page

# %%
#This table gives us the release date and genre of the top 100 movies
pd.read_html(html_page.text) 
df=pd.read_html(html_page.text,index_col=0)[0]
df
df['Released'] = pd.to_datetime(df['Released'])
print (df['Released'].dtype)
df['Month'] = df['Released'].dt.month
df=pd.read_html(html_page.text,index_col=0)[0]
# Out:
# datetime64[ns]

# %%
df=pd.read_html(html_page.text,index_col=0)[0]
df
df['Released'] = pd.to_datetime(df['Released'])
df['Month'] = df['Released'].dt.month
cols = list(df.columns.values)
print(cols)
# Out:
# ['Released', 'Released.1', 'Title', 'Genre', 'DomesticBox Office', 'InternationalBox Office', 'WorldwideBox Office', 'Month']

# %%
df = df[['Released', 'Released.1', 'Month', 'Title', 'Genre', 'DomesticBox Office', 'InternationalBox Office', 'WorldwideBox Office']]

# %%
df
# Out:
#       Released  Released.1  Month                                     Title  \
# 1   2015-12-18        2015     12      Star Wars Ep. VII: The Force Awakens
# 2   2019-04-26        2019      4                         Avengers: Endgame
# 3   2009-12-18        2009     12                                    Avatar
# 4   2018-02-16        2018      2                             Black Panther
# 5   2018-04-27        2018      4                    Avengers: Infinity War
# ..         ...         ...    ...                                       ...
# 96  2007-07-11        2007      7    Harry Potter and the Order of the Pho…
# 97  1980-05-21        1980      5  Star Wars Ep. V: The Empire Strikes Back
# 98  2005-12-09        2005     12    The Chronicles of Narnia: The Lion, t…
# 99  2013-06-14        2013      6                              Man of Steel
# 100 2005-11-18        2005     11       Harry Potter and the Goblet of Fire
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100 entries, 1 to 100
# Data columns (total 8 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Released                 100 non-null    datetime64[ns]
#  1   Released.1               100 non-null    int64
#  2   Month                    100 non-null    int64
#  3   Title                    100 non-null    object
#  4   Genre                    100 non-null    object
#  5   DomesticBox Office       100 non-null    object
#  6   InternationalBox Office  100 non-null    object
#  7   WorldwideBox Office      100 non-null    object
# dtypes: datetime64[ns](1), int64(2), object(5)
# memory usage: 7.0+ KB

# %%
# %matplotlib inline

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib

# %%
#df.groupby('Month')['DomesticBox Office'].sum()
#axis=df[["DomesticBox Office", "Month"]].plot(kind="bar", stacked = False)
#df.groupby([(df.index.year),(df.index.month)]).sum()
df.groupby(['Month']).agg('count')
# Out:
#        Released  Released.1  Title  Genre  DomesticBox Office  \
# Month
# 2             3           3      3      3                   3
# 3             6           6      6      6                   6
# 4             4           4      4      4                   4
# 5            23          23     23     23                  23
# 6            16          16     16     16                  16
# 7            17          17     17     17                  17
# 8             3           3      3      3                   3
# 9             1           1      1      1                   1
# 10            1           1      1      1                   1
# 11           11          11     11     11                  11
# 12           15          15     15     15                  15
#
#        InternationalBox Office  WorldwideBox Office
# Month
# 2                            3                    3
# 3                            6                    6
# ...

# %%
def get_top_movies_per_month(year_list):
        #yearlist = [2020,2019,2040]
        frames = []
        for year in year_list:
            for month in range(1,13):
                url = 'https://www.the-numbers.com/movies/report/All/All/All/All/All/All/All/All/All/None/None/{}/{}/{}/{}/None/None/None/None?show-release-date=On&view-order-by=domestic-box-office&view-order-direction=desc&show-domestic-box-office=On&show-genre=On'.format(year, year, month, month)
                html_page = requests.get(url)
                frames.append(pd.read_html(html_page.text, index_col=0)[0])
        return pd.concat(frames)

# %%
year_list = [2020, 2019]
df = get_top_movies_per_month(year_list)
df
# Out:
#          Released                    Title            Genre DomesticBox Office
# 1    Jan 17, 2020        Bad Boys For Life           Action       $204,417,855
# 2    Jan 17, 2020                 Dolittle        Adventure        $77,047,065
# 3    Jan 24, 2020            The Gentlemen           Action        $36,471,796
# 4    Jan 10, 2020              Like a Boss           Comedy        $22,169,514
# 5     Jan 3, 2020               The Grudge           Horror        $21,216,148
# ..            ...                      ...              ...                ...
# 96   Dec 31, 2019               Jâaccuse            Drama                 $0
# 97   Dec 31, 2019  Je ne rÃªve que de vous            Drama                 $0
# 98   Dec 31, 2019    Wo Wei Xiong Di Kuang            Drama                 $0
# 99   Dec 31, 2019  Justice League Part Two           Action                 $0
# 100  Dec 31, 2019              Singles Day  Romantic Comedy                 $0
#
# [2347 rows x 4 columns]
